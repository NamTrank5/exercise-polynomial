# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import Pipeline
from matplotlib import pyplot as plt 
import numpy as np
import sys

# %%
import sys
num_samples = int(sys.argv[1]) if len(sys.argv) > 1 else 100

def get_ys(xs):
    signal = -0.1*xs**3 + xs**2 - 5*xs - 5
    noise = np.random.normal(0,100,(len(xs),1))
    return signal + noise

X = np.random.uniform(-20,20,num_samples).reshape((num_samples,1))
y = get_ys(X)

plt.scatter(X,y,label="data")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 2
#       1 import sys
# ----> 2 num_samples = int(sys.argv[1]) if len(sys.argv) > 1 else 100
#       4 def get_ys(xs):
#       5     signal = -0.1*xs**3 + xs**2 - 5*xs - 5
#
# ValueError: invalid literal for int() with base 10: '--f=/home/codespace/.local/share/jupyter/runtime/kernel-v3fc061ce1ad1ecc6b233b17209ac2da5cdcd96332.json'
